# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **My name is Chia Edwin**
# __I desisre to be a Data Scientist__

# %% [markdown]
# *I am interested in the data science because*
# _It is the sexiest job in the 21st century_

# %% [markdown]
# ### The python code below will print Hello World!!!

# %%
print("Hello World!!!")
# Out:
# Hello World!!!

# %% [markdown]
# - This is a bullet list
#
# 1. This is a number list
#
# |Name    |Age  |Sex |
# |--------|-----|----|
# |John    |24   |M   |
#
# [click me]
# (https://coursera.com)
#
# ![mydp.jpg](attachment:mydp.jpg)
#
# > This is a blockquote
#
# ~~This is a strikethrough~~
#
# <code style="background:blue;color:white">THIS IS A HIGHLIGHT TEXT</code>
